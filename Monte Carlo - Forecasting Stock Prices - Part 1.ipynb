# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
from scipy.stats import norm
import yfinance as yf

# %matplotlib inline

# %%
ticker = 'PG'
data = pd.DataFrame()
data[ticker] = yf.download(t, start='2007-01-01', end='2023-12-31')['Adj Close']
log_returns = np.log(1+data.pct_change())
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
log_returns.tail()
# Out:
#                   PG
# Date
# 2023-12-22  0.002895
# 2023-12-26  0.000867
# 2023-12-27 -0.002314
# 2023-12-28  0.002025
# 2023-12-29  0.002885

# %%
data.plot(figsize=(10,6));

# %%
log_returns.plot(figsize = (10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
u = log_returns.mean()
u
# Out:
# PG    0.000225
# dtype: float64

# %%
var = log_returns.var()
var
# Out:
# PG    0.000383
# dtype: float64

# %% [markdown]
# drift = u - 1/2 * var

# %%
drift = u - (.5 * var)
drift
# Out:
# PG    0.000033
# dtype: float64

# %%
stdev = log_returns.std()
stdev
# Out:
# PG    0.019582
# dtype: float64
